# %%
import pandas as pd
import numpy as np

df=pd.read_csv('customer_shopping_behavior.csv')
df.sample(5)
# df.info()
# df.describe()
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 2483         2484   32    Male          Skirt     Clothing
# 1194         1195   50    Male         Hoodie     Clothing
# 153           154   69    Male         Hoodie     Clothing
# 3228         3229   37  Female        Jewelry  Accessories
# 769           770   52    Male          Socks     Clothing
#
#       Purchase Amount (USD)        Location Size   Color  Season  \
# 2483                     96         Arizona    S    Teal    Fall
# 1194                     46        New York    S    Teal  Winter
# 153                      55  North Carolina    M  Maroon  Winter
# 3228                     95     Connecticut    M  Yellow  Spring
# 769                     100        Delaware    M  Silver  Spring
#
#       Review Rating Subscription Status   Shipping Type Discount Applied  \
# 2483            2.9                  No        Standard               No
# 1194            3.1                  No  2-Day Shipping              Yes
# 153             3.2                 Yes        Standard              Yes
# 3228            4.6                  No  2-Day Shipping               No
# 769             4.3                 Yes    Store Pickup              Yes
#
#      Promo Code Used  Previous Purchases Payment Method Frequency of Purchases
# 2483              No                   8     Debit Card                Monthly
# 1194             Yes                   6    Credit Card            Fortnightly
# 153              Yes                  22     Debit Card               Annually
# 3228              No                  27         PayPal               Annually
# 769              Yes                   8         PayPal                Monthly

# %%
df['Review Rating'] = df.groupby('Category')['Review Rating'].transform(lambda x: x.fillna(x.median()))

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
df.columns=df.columns.str.replace(' ', '_')
df.columns=df.columns.str.lower()
df=df.rename(columns={'purchase_amount_(usd)':'purchase_amount'})
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='object')

# %%
labels=['Young Adults' , 'Adults' , 'Middle-aged' , 'Seniors']

df['age_group'] = pd.qcut(df['age'], q=4, labels=labels)
# df[['Age', 'age_group']].sample(5)

# %%
frequency_mapping = {
    'Fortnightly': 14,
    'Weekly': 7,
    'Monthly': 30,
    'Quarterly': 90,
    'Bi-Weekly': 14,
    'Annually': 365,
    'Every 3 Months': 90
}

df['purchase_frequency_days'] = df['frequency_of_purchases'].map(frequency_mapping)

# %%
df[['frequency_of_purchases', 'purchase_frequency_days']].sample(5)
# Out:
#      frequency_of_purchases  purchase_frequency_days
# 162               Bi-Weekly                       14
# 1338            Fortnightly                       14
# 1221              Quarterly                       90
# 3166            Fortnightly                       14
# 125          Every 3 Months                       90

# %%
(df['discount_applied'] == df['promo_code_used']).all()
# Out:
# np.True_

# %%
# df=df.drop(columns={'promo_code_used'} , axis=1)
df.head(5)
df.to_csv('customer_shopping_behavior_(updated).csv', index=False)

# %%
# ---------------------------------------------
# PostgreSQL Connection
# Replace the placeholders below with your own
# PostgreSQL credentials before running.
# ---------------------------------------------

from sqlalchemy import create_engine

username = "YOUR_USERNAME"
password = "YOUR_PASSWORD"
host = "localhost"
port = "5432"
database = "customer_behaviour"

engine = create_engine(
    f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}"
)

# %%
# Step 2: Load DataFrame into PostgreSQL

table_name = "customer"      # choose any table name

df.to_sql(
    table_name,
    engine,
    if_exists="replace",
    index=False
)

print(f"Data successfully loaded into table '{table_name}' in database '{database}'.")
# Out:
# Data successfully loaded into table 'customer' in database 'customer_behaviour'.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
